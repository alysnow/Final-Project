# %%
import numpy as np
import pandas as pd
import json

# Python ≥3.5 is required
import sys
#assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
#assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os # operator system

# to make this notebook's output stable across runs
np.random.seed(42)

# %%
# data = pd.read_csv("../Resources/data/test.csv")
# data.head()
# Out:
#      id                              belongs_to_collection   budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...        0
# 1  3002                                                NaN    88000
# 2  3003                                                NaN        0
# 3  3004                                                NaN  6800000
# 4  3005                                                NaN  2000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 4  [{'id': 36, 'name': 'History'}, {'id': 99, 'na...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# 2                                                NaN  tt0118556
# 3             http://www.sonyclassics.com/incendies/  tt1255953
# 4                                                NaN  tt0418753
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
# 2                en             Addicted to Love
# 3                fr                    Incendies
# 4                en           Inside Deep Throat
#
#                                             overview  popularity  ...  \
# 0  Ash and friends (this time accompanied by newc...    3.851534  ...
# 1  When an abused wife grows to giant size becaus...    3.559789  ...
# 2  Good-natured astronomer Sam is devastated when...    8.085194  ...
# 3  A mother's last wishes send twins Jeanne and S...    8.596012  ...
# 4  In 1972, a seemingly typical shoestring budget...    3.217680  ...
#
#                                 production_countries release_date runtime  \
# 0  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...      7/14/07    90.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...      5/19/58    65.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...      5/23/97   100.0
# 3  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...       9/4/10   130.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...      2/11/05    92.0
#
#                                     spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  Somewhere Between Time & Space... A Legend Is ...
# 1  A titanic beauty spreads a macabre wave of hor...
# 2          A Comedy About Lost Loves And Last Laughs
# 3  The search began at the opening of their mothe...
# 4  It was filmed in 6 days for 25 thousand dollar...
#
#                           title  \
# 0  Pokémon: The Rise of Darkrai
# 1   Attack of the 50 Foot Woman
# 2              Addicted to Love
# 3                     Incendies
# 4            Inside Deep Throat
#
#                                             Keywords  \
# 0  [{'id': 11451, 'name': 'pok√©mon'}, {'id': 115...
# 1  [{'id': 9748, 'name': 'revenge'}, {'id': 9951,...
# 2  [{'id': 931, 'name': 'jealousy'}, {'id': 9673,...
# 3  [{'id': 378, 'name': 'prison'}, {'id': 539, 'n...
# 4  [{'id': 279, 'name': 'usa'}, {'id': 1228, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 3, 'character': 'Tonio', 'credit_...
# 1  [{'cast_id': 2, 'character': 'Nancy Fowler Arc...
# 2  [{'cast_id': 11, 'character': 'Maggie', 'credi...
# 3  [{'cast_id': 6, 'character': 'Nawal', 'credit_...
# 4  [{'cast_id': 1, 'character': 'Narrator (voice)...
#
#                                                 crew
# 0  [{'credit_id': '52fe44e7c3a368484e03d683', 'de...
# 1  [{'credit_id': '55807805c3a3685b1300060b', 'de...
# 2  [{'credit_id': '52fe4330c3a36847f8041367', 'de...
# 3  [{'credit_id': '56478092c3a36826140043af', 'de...
# 4  [{'credit_id': '52fe44ce9251416c75041967', 'de...
#
# [5 rows x 22 columns]

# %%
def get_lists(row):
    try:
        return eval(row)
    except:
        return None

# %%
genre = data[['id','genres']]
genre.head()
# Out:
#      id                                             genres
# 0  3001  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  3002  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  3003  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3  3004  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 4  3005  [{'id': 36, 'name': 'History'}, {'id': 99, 'na...

# %%
genre['genres'] = genre['genres'].apply(get_lists)
# Out:
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
genre.head()
# Out:
#      id                                             genres
# 0  3001  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  3002  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  3003  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3  3004  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 4  3005  [{'id': 36, 'name': 'History'}, {'id': 99, 'na...

# %%
json.loads("[{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-43-7dce16e3ca46> in <module>
# ----> 1 json.loads("[{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]")
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)

# %%
eval("[{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]")
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'}]

# %%
genre.to_json(orient='records')
# Out:
# '[{"id":3001,"genres":[{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"}]},{"id":3002,"genres":[{"id":27,"name":"Horror"},{"id":878,"name":"Science Fiction"}]},{"id":3003,"genres":[{"id":35,"name":"Comedy"},{"id":10749,"name":"Romance"}]},{"id":3004,"genres":[{"id":18,"name":"Drama"},{"id":10752,"name":"War"},{"id":9648,"name":"Mystery"}]},{"id":3005,"genres":[{"id":36,"name":"History"},{"id":99,"name":"Documentary"}]},{"id":3006,"genres":[{"id":35,"name":"Comedy"},{"id":18,"name":"Drama"}]},{"id":3007,"genres":[{"id":10749,"name":"Romance"},{"id":18,"name":"Drama"},{"id":35,"name":"Comedy"}]},{"id":3008,"genres":[{"id":16,"name":"Animation"},{"id":10751,"name":"Family"}]},{"id":3009,"genres":[{"id":18,"name":"Drama"},{"id":10749,"name":"Romance"}]},{"id":3010,"genres":[{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":10751,"name":"Family"}]},{"id":3011,"genres":[{"id":53,"name":"Thriller"},{"id":27,"name":"Horror"},{"id":35,"name":"Comedy"}]},{"id":3012,"genres":[{"id":18,"name":"Drama"}]},{"id":3013,"genres":[{"id":28,"name":"Action"},{"id":35,"name":"Comedy"}]},{"id":3014,"genres":[{"id":18,"name":"Drama"},{"id":10749,"name":"Romance"}]},{"id":3015,"genres":[{"id":12,"name":"Adventure"},{"id":35,"name":"Comedy"},{"id":18,"name":"Drama"},{"id":10749,"name":"Romance"}]},{"id":3016,"genres":[{"id":18,"name":"Drama"}]},{"id":3017,"genres":[{"id":878,"name":"Science Fiction"},{"id":35,"name":"Comedy"},{"id":12,"name":"Adventure"}]},{"id":3018,"genres":[{"id":53,"name":"Thriller"},{"id":878,"name":"Science Fiction"},{"id":18,"name":"Drama"},{"id":9648,"name":"Mystery"}]},{"id":3019,"genres":[{"id":18,"name":"Drama"},{"id":10402,"name":"Music"}]},{"id":3020,"genres":[{"id":18,"name":"Drama"},{"id":10749,"name":"Romance"},{"id":53,"name":"Thriller"}]},{"id":3021,"genres":[{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":53,"name":"Thriller"}]},{"id":3022,"genres":[{"id":10749,"name":"Romance"},{"id":35,"name":"Comedy"}]},{"id":3023,"genres":[{"id":18,"name":"Drama"},{"id":10402,"name":"Music"}]},{"id":3024,"genres":[{"id":80,"name":"Crime"},{"id":53,"name":"Thriller"}]},{"id":3025,"genres":[{"id":28,"name":"Action"},{"id":18,"name":"Drama"},{"id":53,"name":"Thriller"}]},{"id":3026,"genres":[{"id":80,"name":"Crime"},{"id":53,"name":"Thriller"}]},{"id":3027,"genres":[{"id":14,"name":"Fantasy"},{"id":12,"name":"Adventure"},{"id":10751,"name":"Family"}]},{"id":3028,"genres":[{"id":80,"name":"Crime"},{"id":53,"name":"Thriller"},{"id":18,"name":"Drama"}]},{"id":3029,"genres":[{"id":18,"name":"Drama"},{"id":10749,"name":"Romance"}]},{"id":3030,"genres":[{"id":28,"name":"Action"},{"id":37,"name":"Western"}]},{"id":3031,"genres":[{"id":10749,"name":"Romance"},{"id":18,"name":"Drama"},{"id":35,"name":"Comedy"}]},{"id":3032,"genres":[{"id":18,"name":"Drama"}]},{"id":3033,"genres":[{"id":18,"name":"Drama"},{"id":35,"name":"Comedy"},{"id":16,"name":"Animation"}]},{"id":3034,"genres":[{"id":99,"name":"Documentary"}]},{"id":3035,"genres":[{"id":35,"name":"Comedy"},{"id":10749,"name":"Romance"}]},{"id":3036,"genres":[{"id":878,"name":"Science Fiction"},{"id":53,"name":"Thriller"}]},{"id":3037,"genres":[{"id":10749,"name":"Romance"},{"id":10402,"name":"Music"},{"id":10751,"name":"Family"}]},{"id":3038,"genres":[{"id":27,"name":"Horror"},{"id":9648,"name":"Mystery"},{"id":53,"name":"Thriller"}]},{"id":3039,"genres":[{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"}]},{"id":3040,"genres":[{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":18,"name":"Drama"},{"id":10752,"name":"War"}]},{"id":3041,"genres":[{"id":35,"name":"Comedy"},{"id":18,"name":"Drama"}]},{"id":3042,"genres":[{"id":28,"name":"Action"},{"id":80,"name":"Crime"},{"id":18,"name":"Drama"},{"id":53,"name":"Thriller"}]},{"id":3043,"genres":[{"id":27,"name":"Horror"},{"id":53,"name":"Thriller"},{"id":35,"name":"Comedy"}]},{"id":3044,"genre ...

# %%
genre['genres'][0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'}]

# %%
genre = genre.explode('genres')

# %%
def get_name(row):
    try:
        return row['name']
    except:
        return None

# %%
genre['genre_name']=genre['genres'].apply(get_name)

# %%
genre.head()
# Out:
#      id                           genres genre_name
# 0  3001  {'id': 12, 'name': 'Adventure'}  Adventure
# 0  3001  {'id': 16, 'name': 'Animation'}  Animation
# 0  3001  {'id': 10751, 'name': 'Family'}     Family
# 0  3001    {'id': 14, 'name': 'Fantasy'}    Fantasy
# 1  3002     {'id': 27, 'name': 'Horror'}     Horror

# %%
pd.json_normalize(genre.to_json(orient='records'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-428f622475c5> in <module>
# ----> 1 pd.json_normalize(genre.to_json(orient='records'))
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     272
#     273     if record_path is None:
# --> 274         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     275             # naive normalization, this is idempotent for flat records
#     276             # and potentially will inflate the data considerably for
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\io\json\_normalize.py in <genexpr>(.0)
#     272
#     273     if record_path is None:
# --> 274         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     275             # naive normalization, this is idempotent for flat records
#     276             # and potentially will inflate the data considerably for
#
# AttributeError: 'str' object has no attribute 'values'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4398 entries, 0 to 4397
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4398 non-null   int64
#  1   belongs_to_collection  877 non-null    object
#  2   budget                 4398 non-null   int64
#  3   genres                 4382 non-null   object
#  4   homepage               1420 non-null   object
#  5   imdb_id                4398 non-null   object
#  6   original_language      4398 non-null   object
#  7   original_title         4398 non-null   object
#  8   overview               4384 non-null   object
#  9   popularity             4398 non-null   float64
#  10  poster_path            4397 non-null   object
#  11  production_companies   4140 non-null   object
#  12  production_countries   4296 non-null   object
#  13  release_date           4397 non-null   object
#  14  runtime                4394 non-null   float64
#  15  spoken_languages       4356 non-null   object
#  16  status                 4396 non-null   object
#  17  tagline                3535 non-null   object
#  18  title                  4395 non-null   object
#  19  Keywords               4005 non-null   object
#  20  cast                   4385 non-null   object
#  21  crew                   4376 non-null   object
# dtypes: float64(2), int64(2), object(18)
# memory usage: 756.0+ KB

# %%
test = (f"'{data.genres[0][1:-1]}'")
test
# Out:
# "'{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}'"

# %%
import json
  
# initializing string 
test_string = test
  
# printing original string 
print("The original string : " + str(test_string))
  
# using json.loads()
# convert dictionary string to dictionary
res = json.loads(test_string)
  
# print result
print("The converted dictionary : " + str(res))
# Out:
# The original string : '{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}'
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-34-dbe0d21c045c> in <module>
#       9 # using json.loads()
#      10 # convert dictionary string to dictionary
# ---> 11 res = json.loads(test_string)
#      12
#      13 # print result
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
